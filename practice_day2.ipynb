# %%
# Use and implement more pandas functions and pratice them to ace the library
import pandas as pd

# %%
# Read CSV using pandas read_csv
df = pd.read_csv(r"C:\Users\Prime\Desktop\Python 1\Python Prwatech\09032024\best-selling-books.csv")

# %%
# Getting first 5 frames of dataset
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
# Getting last 5 rows of dataframe
df.tail()
# Out:
#                                                   Book  \
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions Genre
# 169                           10.0   NaN
# 170                           10.0   NaN
# 171                           10.0   NaN
# 172                           10.0   NaN
# ...

# %%
# Getting sample rows or column from dataframe
df.sample()
# Out:
#                Book                                   Author(s)  \
# 31  Charlotte's Web  E. B. White; illustrated by Garth Williams
#
#    Original language  First published  Approximate sales in millions  \
# 31           English             1952                           50.0
#
#                  Genre
# 31  Children's fiction

# %%
# Getting summary of dataframe, knowing type, names and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Book                           174 non-null    object
#  1   Author(s)                      174 non-null    object
#  2   Original language              174 non-null    object
#  3   First published                174 non-null    int64
#  4   Approximate sales in millions  174 non-null    float64
#  5   Genre                          118 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.3+ KB

# %%
# Lets know the type of each column
print(df.dtypes)
# Out:
# Book                              object
# Author(s)                         object
# Original language                 object
# First published                    int64
# Approximate sales in millions    float64
# Genre                             object
# dtype: object

# %%
# Lets know the size of dataframe
df.size
# Out:
# 1044

# %%
# Lets get tuple of shape(rows,column) of dataframe
df.shape
# Out:
# (174, 6)

# %%
# Lets check whether give axes array is Series(1) or Dataframe(2)
df.ndim
# Out:
# 2

# %%
# Lets get descriptive statistics such as mean minimum maximum deviation etc
df.describe()
# Out:
#        First published  Approximate sales in millions
# count       174.000000                     174.000000
# mean       1962.522989                      30.097126
# std          64.268737                      27.957985
# min        1304.000000                      10.000000
# 25%        1947.000000                      14.000000
# 50%        1974.000000                      20.000000
# 75%        1995.000000                      36.300000
# max        2018.000000                     200.000000

# %%
# Lets get unique values from First published column
df["First published"].unique()
# Out:
# array([1859, 1943, 1997, 1939, 1791, 1937, 1950, 1887, 1992, 2003, 1998,
#        1999, 2000, 2005, 2007, 1988, 1951, 1880, 1984, 1967, 1955, 1946,
#        1908, 1877, 1980, 1975, 1972, 1976, 1952, 1902, 1970, 1969, 1899,
#        1960, 1979, 1991, 1932, 1869, 1881, 1947, 1977, 2002, 1966, 1936,
#        1925, 1938, 1949, 2009, 2008, 1961, 1945, 1788, 1934, 1989, 1935,
#        1993, 2012, 2015, 2010, 1957, 1929, 1974, 1958, 2004, 1971, 1986,
#        1885, 1982, 1813, 1923, 1963, 2006, 1973, 1965, 1964, 1968, 2018,
#        1981, 1995, 2014, 2011, 1994, 1942, 1985, 2001, 1933, 1962, 1956,
#        1987, 1948, 1304, 1978, 2016, 1953, 1996], dtype=int64)

# %%
# Lets get unique values from approximate sales in millions column
df["Approximate sales in millions"].unique()
# Out:
# array([200. , 120. , 100. ,  85. ,  83. ,  80. ,  77. ,  65. ,  60. ,
#         50. ,  45. ,  44. ,  43. ,  40. ,  39. ,  37. ,  36.4,  36. ,
#         35. ,  33. ,  31.5,  31. ,  30. ,  29. ,  28. ,  26. ,  25. ,
#         24. ,  23. ,  22.5,  21. ,  20. ,  18. ,  17. ,  16. ,  15.3,
#         15.2,  15. ,  14. ,  13. ,  12.1,  12. ,  11.5,  11. ,  10.5,
#         10.4,  10. ])

# %%
# Lets get number of unique values from each column
df.nunique(axis=1)
# Out:
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 169    5
# 170    5
# 171    5
# 172    5
# 173    5
# Length: 174, dtype: int64

# %%
# Lets get missing values from dataframe
df.isna()
# Out:
#       Book  Author(s)  Original language  First published  \
# 0    False      False              False            False
# 1    False      False              False            False
# 2    False      False              False            False
# 3    False      False              False            False
# 4    False      False              False            False
# ..     ...        ...                ...              ...
# 169  False      False              False            False
# 170  False      False              False            False
# 171  False      False              False            False
# 172  False      False              False            False
# 173  False      False              False            False
#
#      Approximate sales in millions  Genre
# 0                            False  False
# 1                            False  False
# 2                            False  False
# 3                            False  False
# 4                            False  False
# ...

# %%
# Lets count number of NaN values in each column
df.isna().sum()
# Out:
# Book                              0
# Author(s)                         0
# Original language                 0
# First published                   0
# Approximate sales in millions     0
# Genre                            56
# dtype: int64

# %%
# Lets print rows with NaN values
df[df.isna().any(axis=1)]
# Out:
#                                                   Book  \
# 85                                The Bermuda Triangle
# 110                                The Horse Whisperer
# 115                                      The Outsiders
# 116                          Guess How Much I Love You
# 117                                             Shōgun
# 118                              The Poky Little Puppy
# 120                               Perfume (Das Parfum)
# 121                                The Grapes of Wrath
# 122      The Shadow of the Wind (La sombra del viento)
# 123                            Interpreter of Maladies
# 124                                           Becoming
# 126                               Tuesdays with Morrie
# 127                                  God's Little Acre
# 128     Follow Your Heart (Va' dove ti porta il cuore)
# 129                                  A Wrinkle in Time
# 130                               Long Walk to Freedom
# ...

# %%
# Lets get number of columns in dataframe
df.shape[1]
# Out:
# 6

# %%
# Lets replace the NaN values in dataframe with No Genre value
df["Genre"].fillna("No College", inplace=True)

# %%
# Lets see if changes made got reflected to dataframe or not
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Book, Author(s), Original language, First published, Approximate sales in millions, Genre]
# Index: []

# %%
# Lets get name of columns in dataframe
df.columns
# Out:
# Index(['Book', 'Author(s)', 'Original language', 'First published',
#        'Approximate sales in millions', 'Genre'],
#       dtype='object')

# %%
# Lets sort the dataframe according to First Published in ascending order
df.sort_values('First published',axis=0,ascending=True,inplace=True,na_position='last')

# %%
# Time to check whether changes got reflected tp dataframe or not
df.head()
# Out:
#                                        Book  \
# 140  The Divine Comedy (La Divina Commedia)
# 66                         Paul et Virginie
# 4            Dream of the Red Chamber (紅樓夢)
# 96                      Pride and Prejudice
# 0                      A Tale of Two Cities
#
#                                    Author(s) Original language  \
# 140                          Dante Alighieri           Italian
# 66   Jacques-Henri Bernardin de Saint-Pierre            French
# 4                                 Cao Xueqin           Chinese
# 96                               Jane Austen           English
# 0                            Charles Dickens           English
#
#      First published  Approximate sales in millions  \
# 140             1304                           11.5
# 66              1788                           25.0
# 4               1791                          100.0
# 96              1813                           20.0
# ...

# %%
# Lets get counts of unique values
df.value_counts()
# Out:
# Book                             Author(s)            Original language  First published  Approximate sales in millions  Genre
# A Brief History of Time          Stephen Hawking      English            1988             25.0                           Popular science    1
# The Hobbit                       J. R. R. Tolkien     English            1937             100.0                          Fantasy            1
# The Gospel According to Peanuts  Robert L. Short      English            1965             10.0                           No College         1
# The Grapes of Wrath              John Steinbeck       English            1939             15.0                           No College         1
# The Great Gatsby                 F. Scott Fitzgerald  English            1925             30.0                           Novel, tragedy     1
#                                                                                                                                            ..
# ...

# %%
# Lets get list of years in which multiple books got published and lets find how many
df['First published'].value_counts()
# Out:
# First published
# 1979    5
# 1988    4
# 1974    4
# 2012    4
# 1992    4
#        ..
# 1986    1
# 1987    1
# 1935    1
# 1962    1
# 1304    1
# Name: count, Length: 95, dtype: int64

# %%
# Lets find out n large values in dataset column approximate sale in millions
df.nlargest(5,'Approximate sales in millions')
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
# 5                                The Hobbit          J. R. R. Tolkien
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 4           Chinese             1791                          100.0
# 5           English             1937                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 4         Family saga
# ...

# %%
# Lets find out n smallest values from the dataframe according to Approximate sales in millions
df.nsmallest(5,'Approximate sales in millions')
# Out:
#                                                   Book  \
# 172  The Story of My Experiments with Truth (સત્યના...
# 146                                       Tobacco Road
# 152                          The Stranger (L'Étranger)
# 170                                     Fahrenheit 451
# 157                    Night (Un di Velt Hot Geshvign)
#
#                       Author(s) Original language  First published  \
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 146            Erskine Caldwell           English             1932
# 152                Albert Camus            French             1942
# 170                Ray Bradbury           English             1953
# 157                 Elie Wiesel           Yiddish             1958
#
#      Approximate sales in millions       Genre
# 172                           10.0  No College
# 146                           10.0  No College
# 152                           10.0  No College
# ...

# %%
df.rename(columns={'Book':'NoteBook'})
# Out:
#                                    NoteBook  \
# 140  The Divine Comedy (La Divina Commedia)
# 66                         Paul et Virginie
# 4            Dream of the Red Chamber (紅樓夢)
# 96                      Pride and Prejudice
# 0                      A Tale of Two Cities
# ..                                      ...
# 113             All the Light We Cannot See
# 73                    The Girl on the Train
# 166     The Subtle Art of Not Giving a Fuck
# 106                 Where the Crawdads Sing
# 124                                Becoming
#
#                                    Author(s) Original language  \
# 140                          Dante Alighieri           Italian
# 66   Jacques-Henri Bernardin de Saint-Pierre            French
# 4                                 Cao Xueqin           Chinese
# 96                               Jane Austen           English
# 0                            Charles Dickens           English
# ...

# %%
# Lets change column name to Book again
df.rename(columns={'NoteBook':'Book'},inplace=True)

# %%
# Lets get the indexes of the dataframe
df.index
# Out:
# Index([140,  66,   4,  96,   0,  44,  26,  19,  23,  45,
#        ...
#        114,  72, 135,  83, 145, 113,  73, 166, 106, 124],
#       dtype='int64', length=174)

# %%
# Lets access the group of rows and columns in given dataframe
df.loc[140,'Book']
# Out:
# 'The Divine Comedy (La Divina Commedia)'

# %%
# Lets extract some rows using pandas iloc[] method Getting first five rows of dataset
df.iloc[:5]
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
# lets check if the changes were reflected to dataframe or not
df.iloc[:5]
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
df.sample()
# Out:
#                   Book          Author(s) Original language  First published  \
# 55  Gone with the Wind  Margaret Mitchell           English             1936
#
#     Approximate sales in millions               Genre
# 55                           30.0  Historical fiction

# %%
# Lets change the specific cell to another value
condition = df['Author(s)'] == 'New_Author'
df['Author(s)'] = df['Author(s)'].where(~condition, other='Cao X')

# %%
df.iloc[:5]
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                     Cao X
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
# Lets drop the record from the dataframe
df.drop(index=[0])
# Out:
#                                                   Book  \
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                             And Then There Were None
# 4                       Dream of the Red Chamber (紅樓夢)
# 5                                           The Hobbit
# ..                                                 ...
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 1      Antoine de Saint-Exupéry            French             1943
# 2                 J. K. Rowling           English             1997
# 3               Agatha Christie           English             1939
# ...

# %%
# Lets check whether which column is index column
print(df.index.name)
# Out:
# None

# %%
# Lets print the entries group by year
df.groupby('First published')

# %%
# Lets see the first few records
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
# Lets plot the scatter plot
df.plot(kind = "scatter",x = 'First published', y = 'Approximate sales in millions',color = 'red', marker = 's')
# Out:
# <Axes: xlabel='First published', ylabel='Approximate sales in millions'>

# %%
# Lets find the correlation among the columns using pearson method
# Check for non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['float', 'int']).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Compute the correlation matrix using Pearson method
numeric_df.corr(method='pearson')
# Out:
#                                First published  Approximate sales in millions
# First published                       1.000000                      -0.124346
# Approximate sales in millions        -0.124346                       1.000000

# %%
# Check for non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['float', 'int']).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Compute the sum along the specified axis (axis=0 for sum of each column)
numeric_df.sum(axis=0, skipna=True)
# Out:
# First published                  341479.0
# Approximate sales in millions      5236.9
# dtype: float64

# %%
# Lets find the mean of each numeric column
non_numeric_columns = df.select_dtypes(exclude=['float', 'int']).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Compute the mean along the specified axis (axis=0 for mean of each column)
numeric_df.mean(axis=0, skipna=True)
# Out:
# First published                  1962.522989
# Approximate sales in millions      30.097126
# dtype: float64

# %%
# Lets find the median of the dataframe
# Check for non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['float', 'int']).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Compute the median along the specified axis (axis=0 for median of each column)
numeric_df.median(axis=0, skipna=True)
# Out:
# First published                  1974.0
# Approximate sales in millions      20.0
# dtype: float64

# %%
# Check for non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['float', 'int']).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Compute the standard deviation along the specified axis (axis=0 for standard deviation of each column)
numeric_df.std(axis=0, skipna=True)
# Out:
# First published                  64.268737
# Approximate sales in millions    27.957985
# dtype: float64

# %%
# Lets reset the index of dataframe
df.reset_index(inplace = True)

# %%
# Method to get data from required location
df.at[0,'Author(s)']
# Out:
# 'Charles Dickens'

# %%
df.head()
# Out:
#    index                                      Book                 Author(s)  \
# 0      0                      A Tale of Two Cities           Charles Dickens
# 1      1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2      2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3      3                  And Then There Were None           Agatha Christie
# 4      4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# ...

# %%
# Tofind out duplicate records
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, Book, Author(s), Original language, First published, Approximate sales in millions, Genre]
# Index: []

# %%
# There are no duplicate entries but lets apply a function to remove duplicate entries
df.drop_duplicates()
# Out:
#      index                                               Book  \
# 0        0                               A Tale of Two Cities
# 1        1                The Little Prince (Le Petit Prince)
# 2        2           Harry Potter and the Philosopher's Stone
# 3        3                           And Then There Were None
# 4        4                     Dream of the Red Chamber (紅樓夢)
# ..     ...                                                ...
# 169    169                                           The Goal
# 170    170                                     Fahrenheit 451
# 171    171                                     Angela's Ashes
# 172    172  The Story of My Experiments with Truth (સત્યના...
# 173    173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 0               Charles Dickens           English             1859
# 1      Antoine de Saint-Exupéry            French             1943
# ...

# %%
# Method to drop Na values
df.dropna(axis = 0,how = 'any')
# Out:
#      index                                      Book  \
# 0        0                      A Tale of Two Cities
# 1        1       The Little Prince (Le Petit Prince)
# 2        2  Harry Potter and the Philosopher's Stone
# 3        3                  And Then There Were None
# 4        4            Dream of the Red Chamber (紅樓夢)
# ..     ...                                       ...
# 119    119                  The Pillars of the Earth
# 125    125      The Hitchhiker's Guide to the Galaxy
# 134    134                                 The Giver
# 143    143                              The Exorcist
# 145    145                       Fifty Shades Darker
#
#                     Author(s) Original language  First published  \
# 0             Charles Dickens           English             1859
# 1    Antoine de Saint-Exupéry            French             1943
# 2               J. K. Rowling           English             1997
# ...

# %%
# Lets apply diff method to dataframe
# Select non-string columns
numeric_df = df.select_dtypes(exclude=['object'])

# Compute the difference along the rows (axis 0)
diff_numeric_df = numeric_df.diff()

print(diff_numeric_df)
# Out:
#      index  First published  Approximate sales in millions
# 0      NaN              NaN                            NaN
# 1      1.0             84.0                            0.0
# 2      1.0             54.0                          -80.0
# 3      1.0            -58.0                          -20.0
# 4      1.0           -148.0                            0.0
# ..     ...              ...                            ...
# 169    1.0             10.0                            0.0
# 170    1.0            -31.0                            0.0
# 171    1.0             43.0                            0.0
# 172    1.0            -67.0                            0.0
# 173    1.0             67.0                            0.0
#
# [174 rows x 3 columns]

# %%
# Rank of every respective entry along an axis of the DataFrame passed
df.rank(axis=0, method='average', numeric_only=None, na_option='keep', ascending=True, pct=False)
# Out:
#      index   Book  Author(s)  Original language  First published  \
# 0      1.0    3.0       24.0               72.0              5.0
# 1      2.0  126.0       11.0              140.0             37.0
# 2      3.0   46.0       68.0               72.0            134.5
# 3      4.0    9.0        1.0               72.0             33.0
# 4      5.0   27.0       19.0                2.5              3.0
# ..     ...    ...        ...                ...              ...
# 169  170.0  109.0       42.0               72.0            108.0
# 170  171.0   30.0      132.0               72.0             55.0
# 171  172.0   11.0       52.0               72.0            132.5
# 172  173.0  145.0      119.0              148.0             20.5
# 173  174.0   19.0       61.0               72.0            132.5
#
#      Approximate sales in millions  Genre
# 0                            173.5   53.5
# 1                            173.5   78.0
# 2                            172.0   38.5
# ...
